# %%
import math

# %%
def calculate_area(radius):
    return math.pi * radius ** 2
def calculate_circumference(radius):
    return 2 * math.pi * radius

radius = 5
area = calculate_area(radius)
circumference = calculate_circumference(radius)
print(f"Area of the circle with radius {radius}: {area}")
print(f"Circumference of the circle with radius {radius}: {circumference}")
# Out:
# Area of the circle with radius 5: 78.53981633974483
# Circumference of the circle with radius 5: 31.41592653589793
